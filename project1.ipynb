# %%
name=input("enter the name:")
age=int(input("enter the age:"))

tamil=float(input("enter the tamil mark:"))
english=float(input("enter the english mark:"))
maths=float(input("enter the maths mark:"))
science=float(input("enter the science mark:"))
social_science=float(input("enter the social science mark:"))

total=tamil+english+maths+science+social_science
average=total/5

if average>=90:
    grade="A"
elif average>=80:
    grade="B"
elif average>=70:
    grade="C"
elif average>=60:
    grade="D" 
elif average>=50:
    grade="E" 
else:
    grade="FAIL"

report=f"""
            STUDENT REPORT CARD
Name = {name}
Age = {age}
Tamil mark = {tamil}
English mark = {english}
Maths mark = {maths}
Science mark = {science}
Social Science mark = {social_science}
Total = {total}
Average = {average}
Grade = {grade}
"""
print(report)

try:
    file=open("report_card.txt","w")
    file.write(report)
    file.close()
    print("Report card saved successfully")
except:
    print("Error while saving report card")
# Out:
#             STUDENT REPORT CARD
# Name = kulfi
# Age = 15
# Tamil mark = 98.0
# English mark = 79.0
# Maths mark = 87.0
# Science mark = 97.0
# Social Science mark = 89.0
# Total = 450.0
# Average = 90.0
# Grade = A
#
# Report card saved successfully

# %%
def report_card():

    name=input("enter the name:")
    age=int(input("enter the age:"))

    tamil=float(input("enter the tamil mark:"))
    english=float(input("enter the english mark:"))
    maths=float(input("enter the maths mark:"))
    science=float(input("enter the science mark:"))
    social_science=float(input("enter the social science mark:"))

    if (tamil < 0 or tamil > 100) or (english < 0 or english > 100) or (maths < 0 or maths > 100) or (science < 0 or science > 100) or (social_science < 0 or social_science > 100):
        print("Invalid mark")
        return
    else:
        total=tamil+english+maths+science+social_science
        average=total/5

    if average>=90:
        grade="A"
    elif average>=80:
        grade="B"
    elif average>=70:
        grade="C"
    elif average>=60:
        grade="D" 
    elif average>=50:
        grade="E" 
    else:
        grade="FAIL"

    report=f"""
                STUDENT REPORT CARD
    Name = {name}
    Age = {age}
    Tamil mark = {tamil}
    English mark = {english}
    Maths mark = {maths}
    Science mark = {science}
    Social Science mark = {social_science}
    Total = {total}
    Average = {average}
    Grade = {grade}
    """
    print(report)

    try:
        file=open("report_card.txt","a")
        file.write(report)
        file.close()
        print("Report card saved successfully")
    except:
        print("Error while saving report card")

report_card()
report_card()
# Out:
#                 STUDENT REPORT CARD
#     Name = ruba
#     Age = 20
#     Tamil mark = 98.0
#     English mark = 87.0
#     Maths mark = 78.0
#     Science mark = 88.0
#     Social Science mark = 98.0
#     Total = 449.0
#     Average = 89.8
#     Grade = B
#
# Report card saved successfully
#
#                 STUDENT REPORT CARD
#     Name = sathya
#     Age = 20
#     Tamil mark = 98.0
#     English mark = 89.0
#     Maths mark = 78.0
#     Science mark = 98.0
#     Social Science mark = 89.0
#     Total = 452.0
#     Average = 90.4
#     Grade = A
#
# Report card saved successfully

# %%
def report_card():
    try:
        name=input("enter the name:")
        age=int(input("enter the age:"))

        tamil=float(input("enter the tamil mark:"))
        english=float(input("enter the english mark:"))
        maths=float(input("enter the maths mark:"))
        science=float(input("enter the science mark:"))
        social_science=float(input("enter the social science mark:"))

        if (tamil < 0 or tamil > 100) or (english < 0 or english > 100) or (maths < 0 or maths > 100) or (science < 0 or science > 100) or (social_science < 0 or social_science > 100):
            print("Invalid mark")
            return
        else:
            total=tamil+english+maths+science+social_science
            average=total/5

        if average>=90:
            grade="A"
        elif average>=80:
            grade="B"
        elif average>=70:
            grade="C"
        elif average>=60:
            grade="D" 
        elif average>=50:
            grade="E" 
        else:
            grade="FAIL"

        student = {
        "name": name,
        "age": age,
        "tamil": tamil,
        "english": english,
        "maths": maths,
        "science": science,
        "social_science": social_science,
        "total": total,
        "average": average,
        "grade": grade
        }

        report=(f"""
                STUDENT REPORT CARD

        Name: {student["name"]}
        Age: {student["age"]}

        Tamil: {student["tamil"]}
        English: {student["english"]}
        Maths: {student["maths"]}
        Science: {student["science"]}
        Social Science: {student["social_science"]}

        Total: {student["total"]}
        Average: {student["average"]}
        Grade: {student["grade"]}
        """)

        print(report)

        file=open("report_card.txt","a")
        file.write(report)
        file.close()
        file=open("report_card.txt","r")
        data=file.read()
        print(data)
        file.close()
        print("Report card saved successfully")

    except:
        print("Error")

report_card()
report_card()
# Out:
#                 STUDENT REPORT CARD
#
#         Name: kaviya
#         Age: 20
#
#         Tamil: 98.0
#         English: 89.0
#         Maths: 89.0
#         Science: 79.0
#         Social Science: 67.0
#
#         Total: 422.0
#         Average: 84.4
#         Grade: B
#
#
#             STUDENT REPORT CARD
# Name = kulfi
# Age = 15
# Tamil mark = 98.0
# English mark = 79.0
# Maths mark = 87.0
# Science mark = 97.0
# Social Science mark = 89.0
# Total = 450.0
# Average = 90.0
# Grade = A
#
#                 STUDENT REPORT CARD
#     Name = ruba
#     Age = 20
#     Tamil mark = 98.0
#     English mark = 87.0
#     Maths mark = 78.0
#     Science mark = 88.0
#     Social Science mark = 98.0
#     Total = 449.0
#     Average = 89.8
#     Grade = B
#
#                 STUDENT REPORT CARD
#     Name = sathya
#     Age = 20
#     Tamil mark = 98.0
#     English mark = 89.0
#     Maths mark = 78.0
#     Science mark = 98.0
#     Social Science mark = 89.0
#     Total = 452.0
# ...

# %%
try:
    n = int(input("Enter number of students: "))
    for i in range(n):
        
        name=input("enter the name:")
        age=int(input("enter the age:"))

        tamil=float(input("enter the tamil mark:"))
        english=float(input("enter the english mark:"))
        maths=float(input("enter the maths mark:"))
        science=float(input("enter the science mark:"))
        social_science=float(input("enter the social science mark:"))

        if (tamil < 0 or tamil > 100) or (english < 0 or english > 100) or (maths < 0 or maths > 100) or (science < 0 or science > 100) or (social_science < 0 or social_science > 100):
            print("Invalid mark")
            continue
        else:
            total=tamil+english+maths+science+social_science
            average=total/5

        def grade():

            if average>=90:
                return "A"
            elif average>=80:
                return "B"
            elif average>=70:
                return "C"
            elif average>=60:
                return "D" 
            elif average>=50:
                return "E" 
            else:
                return "FAIL"

        result=grade()

        student = {
        "name": name,
        "age": age,
        "tamil": tamil,
        "english": english,
        "maths": maths,
        "science": science,
        "social_science": social_science,
        "total": total,
        "average": average,
        "grade": result
        }

        report=(f"""
                STUDENT REPORT CARD

        Name: {student["name"]}
        Age: {student["age"]}

        Tamil: {student["tamil"]}
        English: {student["english"]}
        Maths: {student["maths"]}
        Science: {student["science"]}
        Social Science: {student["social_science"]}

        Total: {student["total"]}
        Average: {student["average"]}
        Grade: {student["grade"]}
        """)

        print(report)

        file=open("report_card.txt","a")
        file.write(report)
        file.close()
        file=open("report_card.txt","r")
        data=file.read()
        print(data)
        file.close()
        print("Report card saved successfully")

except:
    print("Error")
# Out:
#                 STUDENT REPORT CARD
#
#         Name: hari
#         Age: 20
#
#         Tamil: 87.0
#         English: 89.0
#         Maths: 87.0
#         Science: 89.0
#         Social Science: 98.0
#
#         Total: 450.0
#         Average: 90.0
#         Grade: A
#
#
#             STUDENT REPORT CARD
# Name = kulfi
# Age = 15
# Tamil mark = 98.0
# English mark = 79.0
# Maths mark = 87.0
# Science mark = 97.0
# Social Science mark = 89.0
# Total = 450.0
# Average = 90.0
# Grade = A
#
#                 STUDENT REPORT CARD
#     Name = ruba
#     Age = 20
#     Tamil mark = 98.0
#     English mark = 87.0
#     Maths mark = 78.0
#     Science mark = 88.0
#     Social Science mark = 98.0
#     Total = 449.0
#     Average = 89.8
#     Grade = B
#
#                 STUDENT REPORT CARD
#     Name = sathya
#     Age = 20
#     Tamil mark = 98.0
#     English mark = 89.0
#     Maths mark = 78.0
#     Science mark = 98.0
#     Social Science mark = 89.0
#     Total = 452.0
# ...
